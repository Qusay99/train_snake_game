# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("training_protokoll.csv")

# %%
df.describe()
# Out:
#        generation  gen_highest_Fitness  gen_higest_score
# count  200.000000           200.000000        200.000000
# mean    99.500000        205315.470000         40.065000
# std     57.879185         87149.163579         17.014649
# min      0.000000          5150.000000          1.000000
# 25%     49.750000        226000.000000         44.000000
# 50%     99.500000        246000.000000         48.000000
# 75%    149.250000        251000.000000         49.000000
# max    199.000000        286000.000000         56.000000

# %%
figure, axes = plt.subplots(nrows=2, ncols=1, figsize = (14,14))

axes[0].set_title("Höchst ereichter Fitnesswert vs. Generation")
axes[0].set_xlabel("Generation")
axes[0].set_ylabel("Wert der Fitnessfunktion")
axes[0].plot(df['gen_highest_Fitness'].values, c='#4424D6')

axes[1].set_title("Höchst erreichter Score vs. Generation")
axes[1].set_xlabel("Generation")
axes[1].set_ylabel("Höchst erreichter Score")
axes[1].plot(df['gen_higest_score'].values,c='#FB9902')
